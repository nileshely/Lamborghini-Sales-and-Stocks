# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel('/kaggle/input/lamborghini-sales-and-stocks/LamboData.xlsx')

# %%
df.head(2)
# Out:
#    Year  Sales     Growth  Open   High   Low  Close
# 0  2006   2087        NaN    5.5  11.3   5.5  11.30
# 1  2007   2406  15.285098   11.8  26.3  11.8  23.05

# %%
df.shape
# Out:
# (18, 7)

# %%
df.columns
# Out:
# Index(['Year', 'Sales', 'Growth', 'Open ', 'High', 'Low', 'Close'], dtype='object')

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Year', y="Sales", color='green', marker='o', markersize=8, linewidth=2)  # Change color to green
plt.title("Sales Trend Over Years", fontsize=16, fontweight='bold', color='navy')
plt.xlabel("Year", fontsize=14, fontweight='bold', color='darkgreen')
plt.ylabel("Sales", fontsize=14, fontweight='bold', color='darkgreen')
plt.xticks(fontsize=12, fontweight='bold', color='dimgray')
plt.yticks(fontsize=12, fontweight='bold', color='dimgray')
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))  # Remove decimal from y-axis labels
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(['Sales'], loc='upper left', fontsize=12)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Year', y="Growth", color='green', marker='o', markersize=8, linewidth=2)  # Change color to green
plt.title("Sales Growth Over Years", fontsize=16, fontweight='bold', color='navy')
plt.xlabel("Year", fontsize=14, fontweight='bold', color='darkgreen')
plt.ylabel("Growth", fontsize=14, fontweight='bold', color='darkgreen')
plt.xticks(fontsize=12, fontweight='bold', color='dimgray')
plt.yticks(fontsize=12, fontweight='bold', color='dimgray')
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))  # Remove decimal from y-axis labels
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(['Growth'], loc='upper left', fontsize=12)
plt.rcParams['text.color'] = 'green'
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Year'].astype(int), df['Open '], color='yellow', label='Opening Prices')
plt.plot(df['Year'].astype(int), df['High'], color='red', label='High Prices')
plt.plot(df['Year'].astype(int), df['Low'], color='blue', label='Low Prices')
plt.plot(df['Year'].astype(int), df['Close'], color='purple', label='Closing Prices')
plt.title('Values of Stocks Over Years', fontsize=16, fontweight='bold', color='navy')
plt.xlabel('Year', fontsize=14, fontweight='bold', color='darkgreen')
plt.ylabel('Price', fontsize=14, fontweight='bold', color='darkgreen')
plt.xticks(rotation=45, fontsize=12, fontweight='bold', color='dimgray')
plt.gca().xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
df2 = pd.read_csv('/kaggle/input/lamborghini-sales-and-stocks/Lambo-Future.csv')

# %%
df2
# Out:
#            Sales      Growth
# 0    9084.065359  -10.165493
# 1    9585.733058   -5.204380
# 2   10087.400757   -0.243268
# 3   10589.068455    4.717845
# 4   11090.736154    9.678957
# 5   11592.403853   14.640070
# 6   12094.071551   19.601182
# 7   12595.739250   24.562295
# 8   13097.406949   29.523407
# 9   13599.074647   34.484520
# 10  14100.742346   39.445632
# 11  14602.410045   44.406745
# 12  15104.077743   49.367857
# 13  15605.745442   54.328970
# 14  16107.413141   59.290082
# 15  16609.080839   64.251195
# 16  17110.748538   69.212308
# 17  17612.416237   74.173420
# 18  18114.083935   79.134533
# 19  18615.751634   84.095645
# 20  19117.419333   89.056758
# 21  19619.087031   94.017870
# 22  20120.754730   98.978983
# 23  20622.422429  103.940095
# 24  21124.090127  108.901208
# 25  21625.757826  113.862320
# 26  22127.425525  118.823433
# 27  22629.093223  123.784545
# 28  23130.760922  128.745658
# 29  23632.428621  133.706770
# 30  24134.096319  138.667883
# ...

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(range(len(df)), df['Sales'], color='blue', marker='o', label='Sales')
ax1.set_xlabel('Period', fontsize=14)
ax1.set_ylabel('Sales', fontsize=14, color='blue')

ax2 = ax1.twinx()
ax2.plot(range(len(df)), df['Growth'], color='green', marker='s', label='Growth')
ax2.set_ylabel('Growth', fontsize=14, color='green')

ax1.set_xticks(range(len(df)))
ax1.set_xticklabels(range(1, len(df) + 1), fontsize=12)

ax1.yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
ax2.yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

plt.title('Sales and Growth Comparison', fontsize=16, fontweight='bold')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.grid(True)
plt.show()
